# %% [markdown]
# ## **Document Loaders In LangChain**

# %% [markdown]
# #### **TextLoader and CSVLoader**

# %%
from langchain_community.document_loaders import TextLoader, CSVLoader

text_loader = TextLoader("nvda_news_1.txt")
text_loader.load()
# Out:
# [Document(metadata={'source': 'nvda_news_1.txt'}, page_content="The stock of NVIDIA Corp (NASDAQ:NVDA) experienced a daily loss of -3.56% and a 3-month gain of 32.35%. With an Earnings Per Share (EPS) (EPS) of $1.92, the question arises: is the stock significantly overvalued? This article aims to provide a detailed valuation analysis of NVIDIA, offering insights into its financial strength, profitability, growth, and more. We invite you to delve into this comprehensive analysis.\n\nCompany Overview\nWarning! GuruFocus has detected 10 Warning Signs with NVDA. Click here to check it out.\n\nNVDA 30-Year Financial Data\n\nThe intrinsic value of NVDA\n\n\nNVIDIA Corp (NASDAQ:NVDA) is a leading designer of discrete graphics processing units that enhance the experience on computing platforms. The firm's chips are widely used in various end markets, including PC gaming and data centers. In recent years, NVIDIA has broadened its focus from traditional PC graphics applications such as gaming to more complex and favorable opportunities, including artificial intelligence and autonomous driving, leveraging the high-performance capabilities of its products.\n\nCurrently, NVIDIA's stock price stands at $418.01, significantly higher than the GF Value of $310.28, indicating the stock might be overvalued. With a market cap of $1 trillion, the valuation seems steep. The following analysis aims to delve deeper into the company's value.\n\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nUnderstanding the GF Value\nThe GF Value is a unique measure of the intrinsic value of a stock, calculated based on historical trading multiples, a GuruFocus adjustment factor, and future business performance estimates. If the stock price is significantly above the GF Value Line, it is overvalued, and its future return is likely to be poor. Conversely, if it is significantly below the GF Value Line, its future return will likely be higher.\n\nAccording to GuruFocus Value calculation, NVIDIA (NASDAQ:NVDA) appears to be significantly overvalued. The stock's current price of $418.01 per share and the market cap of $1 trillion further strengthen this assumption.\n\nGiven that NVIDIA is significantly overvalued, the long-term return of its stock is likely to be much lower than its future business growth.\n\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nLink: These companies may deliver higher future returns at reduced risk.\n\nFinancial Strength of NVIDIA\nExamining the financial strength of a company is crucial before investing in its stock. Companies with poor financial strength pose a higher risk of permanent loss. NVIDIA's cash-to-debt ratio of 1.27 is worse than 58.04% of companies in the Semiconductors industry. However, NVIDIA's overall financial strength is 8 out of 10, indicating a strong financial position.\n\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nIs NVIDIA's Stock Significantly Overvalued? A Comprehensive Valuation Analysis\nProfitability and Growth\nConsistent profitability over the long term reduces the risk for investors. NVIDIA, with its profitability ranking of 10 out of 10, has been profitable for the past 10 years. The company's operating margin of 17.37% ranks better than 76.5% of companies in the Semiconductors industry.\n\nHowever, growth is a crucial factor in a company's valuation. NVIDIA's growth ranks worse than 52.99% of companies in the Semiconductors industry, with its 3-year average revenue growth rate better than 87.88% of companies in the industry.\n\nROIC vs WACC\nComparing a company's return on invested capital (ROIC) to its weighted average cost of capital (WACC) is an effective way to evaluate its profitability. Over the past 12 months, NVIDIA's ROIC was 20.32 while its W ...

# %%
type(text_loader)
# Out:
# langchain_community.document_loaders.text.TextLoader

# %%
text_loader.file_path
# Out:
# 'nvda_news_1.txt'

# %% [markdown]
# #### **CSVLoader**

# %%
csv_loader = CSVLoader(file_path="movies.csv",source_column="title")
csv_data = csv_loader.load()
csv_data
# Out:
# [Document(metadata={'source': 'K.G.F: Chapter 2', 'row': 0}, page_content='movie_id: 101\ntitle: K.G.F: Chapter 2\nindustry: Bollywood\nrelease_year: 2022\nimdb_rating: 8.4\nstudio: Hombale Films\nlanguage_id: 3\nbudget: 1\nrevenue: 12.5\nunit: Billions\ncurrency: INR'),
#  Document(metadata={'source': 'Doctor Strange in the Multiverse of Madness', 'row': 1}, page_content='movie_id: 102\ntitle: Doctor Strange in the Multiverse of Madness\nindustry: Hollywood\nrelease_year: 2022\nimdb_rating: 7\nstudio: Marvel Studios\nlanguage_id: 5\nbudget: 200\nrevenue: 954.8\nunit: Millions\ncurrency: USD'),
#  Document(metadata={'source': 'Thor: The Dark World', 'row': 2}, page_content='movie_id: 103\ntitle: Thor: The Dark World\nindustry: Hollywood\nrelease_year: 2013\nimdb_rating: 6.8\nstudio: Marvel Studios\nlanguage_id: 5\nbudget: 165\nrevenue: 644.8\nunit: Millions\ncurrency: USD'),
#  Document(metadata={'source': 'Thor: Ragnarok', 'row': 3}, page_content='movie_id: 104\ntitle: Thor: Ragnarok\nindustry: Hollywood\nrelease_year: 2017\nimdb_rating: 7.9\nstudio: Marvel Studios\nlanguage_id: 5\nbudget: 180\nrevenue: 854\nunit: Millions\ncurrency: USD'),
#  Document(metadata={'source': 'Thor: Love and Thunder', 'row': 4}, page_content='movie_id: 105\ntitle: Thor: Love and Thunder\nindustry: Hollywood\nrelease_year: 2022\nimdb_rating: 6.8\nstudio: Marvel Studios\nlanguage_id: 5\nbudget: 250\nrevenue: 670\nunit: Millions\ncurrency: USD'),
#  Document(metadata={'source': 'Sholay', 'row': 5}, page_content='movie_id: 106\ntitle: Sholay\nindustry: Bollywood\nrelease_year: 1975\nimdb_rating: 8.1\nstudio: United Producers\nlanguage_id: 1\nbudget: Not Available\nrevenue: Not Available\nunit: Not Available\ncurrency: Not Available'),
#  Document(metadata={'source': 'Dilwale Dulhania Le Jayenge', 'row': 6}, page_content='movie_id: 107\ntitle: Dilwale Dulhania Le Jayenge\nindustry: Bollywood\nrelease_year: 1995\nimdb_rating: 8\nstudio: Yash Raj Films\nlanguage_id: 1\nbudget: 400\nrevenue: 2000\nunit: Millions\ncurrency: INR'),
#  Document(metadata={'source': '3 Idiots', 'row': 7}, page_content='movie_id: 108\ntitle: 3 Idiots\nindustry: Bollywood\nrelease_year: 2009\nimdb_rating: 8.4\nstudio: Vinod Chopra Films\nlanguage_id: 1\nbudget: 550\nrevenue: 4000\nunit: Millions\ncurrency: INR'),
#  Document(metadata={'source': 'Kabhi Khushi Kabhie Gham', 'row': 8}, page_content='movie_id: 109\ntitle: Kabhi Khushi Kabhie Gham\nindustry: Bollywood\nrelease_year: 2001\nimdb_rating: 7.4\nstudio: Dharma Productions\nlanguage_id: 1\nbudget: 390\nrevenue: 1360\nunit: Millions\ncurrency: INR')]

# %%
csv_data[1].page_content
# Out:
# 'movie_id: 102\ntitle: Doctor Strange in the Multiverse of Madness\nindustry: Hollywood\nrelease_year: 2022\nimdb_rating: 7\nstudio: Marvel Studios\nlanguage_id: 5\nbudget: 200\nrevenue: 954.8\nunit: Millions\ncurrency: USD'

# %%
csv_data[1].metadata
# Out:
# {'source': 'Doctor Strange in the Multiverse of Madness', 'row': 1}

# %% [markdown]
# #### **UnstructuredURLLoader**

# %% [markdown]
# UnstructuredURLLoader of Langchain internally uses unstructured python library to load the content from url's

# %%
#installing necessary libraries, libmagic is used for file type detection
# !pip3 install unstructured libmagic python-magic python-magic-bin
# Out:
# Collecting unstructured
#   Using cached unstructured-0.18.18-py3-none-any.whl.metadata (25 kB)
# Collecting libmagic
#   Using cached libmagic-1.0-py3-none-any.whl
# Collecting python-magic
#   Using cached python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting python-magic-bin
#   Using cached python_magic_bin-0.4.14-py2.py3-none-win_amd64.whl.metadata (710 bytes)
# Requirement already satisfied: charset-normalizer in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from unstructured) (3.4.4)
# Requirement already satisfied: filetype in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: lxml in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from unstructured) (6.0.2)
# Collecting nltk (from unstructured)
#   Using cached nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: requests in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from unstructured) (2.32.5)
# Collecting beautifulsoup4 (from unstructured)
#   Using cached beautifulsoup4-4.14.2-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: emoji in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from unstructured) (2.15.0)
# Requirement already satisfied: dataclasses-json in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from unstructured) (0.6.7)
# Requirement already satisfied: python-iso639 in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from unstructured) (2025.2.18)
# Requirement already satisfied: langdetect in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from unstructured) (1.0.9)
# Requirement already satisfied: numpy in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from unstructured) (2.3.4)
# Requirement already satisfied: rapidfuzz in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from unstructured) (3.14.3)
# Requirement already satisfied: backoff in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from unstructured) (2.2.1)
# Requirement already satisfied: typing-extensions in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from unstructured) (4.15.0)
# Collecting unstructured-client (from unstructured)
#   Using cached unstructured_client-0.42.3-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: wrapt in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from unstructured) (2.0.1)
# Requirement already satisfied: tqdm in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from unstructured) (4.67.1)
# Requirement already satisfied: psutil in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from unstructured) (7.1.3)
# Requirement already satisfied: python-oxmsg in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from unstructured) (0.0.2)
# Requirement already satisfied: html5lib in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from unstructured) (1.1)
# Collecting soupsieve>1.2 (from beautifulsoup4->unstructured)
#   Using cached soupsieve-2.8-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from dataclasses-json->unstructured) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: packaging>=17.0 in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->unstructured) (25.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.1.0)
# Requirement already satisfied: six>=1.9 in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from html5lib->unstructured) (1.17.0)
# Collecting webencodings (from html5lib->unstructured)
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: click in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from nltk->unstructured) (8.3.0)
# Collecting joblib (from nltk->unstructured)
#   Using cached joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: regex>=2021.8.3 in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from nltk->unstructured) (2025.11.3)
# Requirement already satisfied: colorama in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from click->nltk->unstructured) (0.4.6)
# Requirement already satisfied: olefile in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from python-oxmsg->unstructured) (0.47)
# Requirement already satisfied: idna<4,>=2.5 in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from requests->unstructured) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from requests->unstructured) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from requests->unstructured) (2025.10.5)
# Requirement already satisfied: aiofiles>=24.1.0 in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from unstructured-client->unstructured) (25.1.0)
# Collecting cryptography>=3.1 (from unstructured-client->unstructured)
#   Using cached cryptography-46.0.3-cp311-abi3-win_amd64.whl.metadata (5.7 kB)
# Requirement already satisfied: httpcore>=1.0.9 in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from unstructured-client->unstructured) (1.0.9)
# Requirement already satisfied: httpx>=0.27.0 in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from unstructured-client->unstructured) (0.28.1)
# Requirement already satisfied: pydantic>=2.11.2 in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from unstructured-client->unstructured) (2.12.4)
# Requirement already satisfied: pypdf>=4.0 in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from unstructured-client->unstructured) (6.1.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from unstructured-client->unstructured) (1.0.0)
# Collecting cffi>=2.0.0 (from cryptography>=3.1->unstructured-client->unstructured)
#   Using cached cffi-2.0.0-cp312-cp312-win_amd64.whl.metadata (2.6 kB)
# Collecting pycparser (from cffi>=2.0.0->cryptography>=3.1->unstructured-client->unstructured)
#   Using cached pycparser-2.23-py3-none-any.whl.metadata (993 bytes)
# Requirement already satisfied: h11>=0.16 in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from httpcore>=1.0.9->unstructured-client->unstructured) (0.16.0)
# Requirement already satisfied: anyio in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (4.11.0)
# Requirement already satisfied: annotated-types>=0.6.0 in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (0.4.2)
# Requirement already satisfied: sniffio>=1.1 in e:\langchain_finance_news_research_tool_project\env\lib\site-packages (from anyio->httpx>=0.27.0->unstructured-client->unstructured) (1.3.1)
# Using cached unstructured-0.18.18-py3-none-any.whl (1.8 MB)
# Using cached python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Using cached python_magic_bin-0.4.14-py2.py3-none-win_amd64.whl (409 kB)
# Using cached beautifulsoup4-4.14.2-py3-none-any.whl (106 kB)
# Using cached soupsieve-2.8-py3-none-any.whl (36 kB)
# Using cached nltk-3.9.2-py3-none-any.whl (1.5 MB)
# Using cached joblib-1.5.2-py3-none-any.whl (308 kB)
# Using cached unstructured_client-0.42.3-py3-none-any.whl (207 kB)
# Using cached cryptography-46.0.3-cp311-abi3-win_amd64.whl (3.5 MB)
# Using cached cffi-2.0.0-cp312-cp312-win_amd64.whl (183 kB)
# Using cached pycparser-2.23-py3-none-any.whl (118 kB)
# Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Installing collected packages: webencodings, python-magic-bin, libmagic, soupsieve, python-magic, pycparser, joblib, nltk, cffi, beautifulsoup4, cryptography, unstructured-client, unstructured
#
#    ------ ---------------------------------  2/13 [libmagic]
#    ------------ ---------------------------  4/13 [python-magic]
#    --------------- ------------------------  5/13 [pycparser]
#    --------------- ------------------------  5/13 [pycparser]
#    ------------------ ---------------------  6/13 [joblib]
#    ------------------ ---------------------  6/13 [joblib]
#    ------------------ ---------------------  6/13 [joblib]
#    ------------------ ---------------------  6/13 [joblib]
#    ------------------ ---------------------  6/13 [joblib]
#    ------------------ ---------------------  6/13 [joblib]
#    ------------------ ---------------------  6/13 [joblib]
#    ------------------ ---------------------  6/13 [joblib]
#    ------------------ ---------------------  6/13 [joblib]
#    ------------------ ---------------------  6/13 [joblib]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    --------------------- ------------------  7/13 [nltk]
#    ------------------------ ---------------  8/13 [cffi]
#    ------------------------ ---------------  8/13 [cffi]
#    ------------------------ ---------------  8/13 [cffi]
#    --------------------------- ------------  9/13 [beautifulsoup4]
#    --------------------------- ------------  9/13 [beautifulsoup4]
#    ------------------------------ --------- 10/13 [cryptography]
#    ------------------------------ --------- 10/13 [cryptography]
#    ------------------------------ --------- 10/13 [cryptography]
#    ------------------------------ --------- 10/13 [cryptography]
#    ------------------------------ --------- 10/13 [cryptography]
#    ------------------------------ --------- 10/13 [cryptography]
#    ------------------------------ --------- 10/13 [cryptography]
#    ------------------------------ --------- 10/13 [cryptography]
#    --------------------------------- ------ 11/13 [unstructured-client]
#    --------------------------------- ------ 11/13 [unstructured-client]
#    --------------------------------- ------ 11/13 [unstructured-client]
#    --------------------------------- ------ 11/13 [unstructured-client]
#    --------------------------------- ------ 11/13 [unstructured-client]
#    --------------------------------- ------ 11/13 [unstructured-client]
#    --------------------------------- ------ 11/13 [unstructured-client]
#    --------------------------------- ------ 11/13 [unstructured-client]
#    --------------------------------- ------ 11/13 [unstructured-client]
#    --------------------------------- ------ 11/13 [unstructured-client]
#    --------------------------------- ------ 11/13 [unstructured-client]
#    --------------------------------- ------ 11/13 [unstructured-client]
#    --------------------------------- ------ 11/13 [unstructured-client]
#    --------------------------------- ------ 11/13 [unstructured-client]
#    --------------------------------- ------ 11/13 [unstructured-client]
#    --------------------------------- ------ 11/13 [unstructured-client]
#    --------------------------------- ------ 11/13 [unstructured-client]
#    --------------------------------- ------ 11/13 [unstructured-client]
#    --------------------------------- ------ 11/13 [unstructured-client]
#    ------------------------------------ --- 12/13 [unstructured]
#    ------------------------------------ --- 12/13 [unstructured]
#    ------------------------------------ --- 12/13 [unstructured]
#    ------------------------------------ --- 12/13 [unstructured]
#    ------------------------------------ --- 12/13 [unstructured]
#    ------------------------------------ --- 12/13 [unstructured]
#    ------------------------------------ --- 12/13 [unstructured]
#    ------------------------------------ --- 12/13 [unstructured]
#    ------------------------------------ --- 12/13 [unstructured]
#    ------------------------------------ --- 12/13 [unstructured]
#    ------------------------------------ --- 12/13 [unstructured]
#    ------------------------------------ --- 12/13 [unstructured]
#    ------------------------------------ --- 12/13 [unstructured]
#    ------------------------------------ --- 12/13 [unstructured]
#    ------------------------------------ --- 12/13 [unstructured]
#    ------------------------------------ --- 12/13 [unstructured]
#    ------------------------------------ --- 12/13 [unstructured]
#    ------------------------------------ --- 12/13 [unstructured]
#    ------------------------------------ --- 12/13 [unstructured]
#    ------------------------------------ --- 12/13 [unstructured]
#    ------------------------------------ --- 12/13 [unstructured]
#    ---------------------------------------- 13/13 [unstructured]
#
# Successfully installed beautifulsoup4-4.14.2 cffi-2.0.0 cryptography-46.0.3 joblib-1.5.2 libmagic-1.0 nltk-3.9.2 pycparser-2.23 python-magic-0.4.27 python-magic-bin-0.4.14 soupsieve-2.8 unstructured-0.18.18 unstructured-client-0.42.3 webencodings-0.5.1
# & was unexpected at this time.
# The value specified in an AutoRun registry key could not be parsed.

# %%
from langchain_community.document_loaders import UnstructuredURLLoader

# %%
loader = UnstructuredURLLoader(
    urls = [
        "https://www.moneycontrol.com/news/business/banks/hdfc-bank-re-appoints-sanmoy-chakrabarti-as-chief-risk-officer-11259771.html",
        "https://www.moneycontrol.com/news/business/markets/market-corrects-post-rbi-ups-inflation-forecast-icrr-bet-on-these-top-10-rate-sensitive-stocks-ideas-11142611.html"
    ]
)

# %%
data = loader.load()
len(data)
# Out:
# 2

# %%
data[0].page_content[0:100]
# Out:
# 'English\n\nHindi\n\nGujarati\n\nSpecials\n\nHello, Login\n\nHello, Login\n\nLog-inor Sign-Up\n\nMy Account\n\nMy Pro'

# %%
data[0].metadata
# Out:
# {'source': 'https://www.moneycontrol.com/news/business/banks/hdfc-bank-re-appoints-sanmoy-chakrabarti-as-chief-risk-officer-11259771.html'}

# %% [markdown]
# #### **Text Splitters**

# %% [markdown]
# Why do we need text splitters in first place?
#
# LLM's have token limits. Hence we need to split the text which can be large into small chunks so that each chunk size is under the token limit. There are various text splitter classes in langchain that allows us to do this.

# %%
# Taking some random text from wikipedia

text = """Interstellar is a 2014 epic science fiction film co-written, directed, and produced by Christopher Nolan. 
It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, Bill Irwin, Ellen Burstyn, Matt Damon, and Michael Caine. 
Set in a dystopian future where humanity is embroiled in a catastrophic blight and famine, the film follows a group of astronauts who travel through a wormhole near Saturn in search of a new home for humankind.

Brothers Christopher and Jonathan Nolan wrote the screenplay, which had its origins in a script Jonathan developed in 2007 and was originally set to be directed by Steven Spielberg. 
Kip Thorne, a Caltech theoretical physicist and 2017 Nobel laureate in Physics,[4] was an executive producer, acted as a scientific consultant, and wrote a tie-in book, The Science of Interstellar. 
Cinematographer Hoyte van Hoytema shot it on 35 mm movie film in the Panavision anamorphic format and IMAX 70 mm. Principal photography began in late 2013 and took place in Alberta, Iceland, and Los Angeles. 
Interstellar uses extensive practical and miniature effects, and the company Double Negative created additional digital effects.

Interstellar premiered in Los Angeles on October 26, 2014. In the United States, it was first released on film stock, expanding to venues using digital projectors. The film received generally positive reviews from critics and grossed over $677 million worldwide ($715 million after subsequent re-releases), making it the tenth-highest-grossing film of 2014. 
It has been praised by astronomers for its scientific accuracy and portrayal of theoretical astrophysics.[5][6][7] Interstellar was nominated for five awards at the 87th Academy Awards, winning Best Visual Effects, and received numerous other accolades."""

# %% [markdown]
# #### **Manual approach of splitting the text into chunks**

# %%
# Say LLM token limit is 100, in that case we can do simple thing such as this

text[0:100]
# Out:
# 'Interstellar is a 2014 epic science fiction film co-written, directed, and produced by Christopher N'
